# %% [markdown]
# # Robotics Notebook: State-Space Feedback, Saturation, and Safety
#
# This notebook is a companion scaffold for the article. It loads the Python simulation output and supports exploration of tracking error, actuator saturation, timing jitter, and safety states.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
sim_path = root / 'outputs' / 'python_state_space_feedback_simulation.csv'
if sim_path.exists():
    sim = pd.read_csv(sim_path)
else:
    from python.state_space_feedback_simulation import simulate_feedback_loop
    sim = simulate_feedback_loop()
sim.head()

# %%
summary = sim[['tracking_error', 'command', 'loop_jitter_ms']].describe()
saturation_rate = sim['saturated'].mean()
summary, saturation_rate

# %% [markdown]
# # Acquisition Quality Review
#
# Load sample acquisition events and summarize measurement-quality evidence.

# %%
import pandas as pd
events = pd.read_csv('../data/acquisition_events.csv')
events.groupby(['site_id','device_id'])[['timestamp_jitter_ms','buffer_age_ms','bus_retries']].max()

# %% [markdown]
# # R Notebook: Lifecycle Compliance and Update Status Reporting
#
# This notebook summarizes lifecycle, support-state, and OTA readiness data across an edge fleet.

# %%
library(readr)
library(dplyr)

fleet <- read_csv('../data/sample_device_fleet.csv', show_col_types = FALSE)
fleet |> count(site, support_state, rollout_ring)

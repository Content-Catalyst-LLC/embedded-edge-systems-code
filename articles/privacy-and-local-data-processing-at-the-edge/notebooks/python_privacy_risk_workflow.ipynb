# %% [markdown]
# # Python Notebook: Local Edge Privacy Risk Scoring
# This notebook demonstrates privacy-risk scoring for local edge processing.

# %%
from pathlib import Path
import pandas as pd
root = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
events = pd.read_csv(root / 'data' / 'sample_edge_privacy_events.csv')
events.head()

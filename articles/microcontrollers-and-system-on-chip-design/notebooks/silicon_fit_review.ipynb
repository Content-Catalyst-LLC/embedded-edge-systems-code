# %% [markdown]
# # Silicon-Fit Review
#
# Load candidate platforms and device requirements for an initial platform-selection review.

# %%
import pandas as pd
platforms = pd.read_csv('../data/candidate_platforms.csv')
requirements = pd.read_csv('../data/device_requirements.csv')
platforms[['platform_name','platform_type','cpu_mhz','flash_kb','sram_kb','active_ma','sleep_ua','lifecycle_support_score']]

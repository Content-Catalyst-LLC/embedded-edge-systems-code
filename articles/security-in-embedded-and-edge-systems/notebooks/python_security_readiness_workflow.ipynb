# %% [markdown]
# # Python Notebook: Embedded Security Readiness Scoring
# This notebook demonstrates security-readiness scoring for embedded and edge assets.

# %%
from pathlib import Path
import pandas as pd
root = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
assets = pd.read_csv(root / 'data' / 'sample_security_assets.csv')
assets.head()

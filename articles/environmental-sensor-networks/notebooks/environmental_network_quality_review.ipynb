# %% [markdown]
# # Environmental Network Quality Review
#
# Load environmental measurement events and summarize node-level quality evidence.

# %%
import pandas as pd
measurements = pd.read_csv('../data/environmental_measurements.csv')
measurements.groupby(['site_id','node_id'])[['battery_v','link_quality','packet_retries','buffer_age_s']].agg(['min','mean','max'])

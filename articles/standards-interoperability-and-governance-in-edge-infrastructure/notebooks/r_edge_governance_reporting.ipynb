# %% [markdown]
# # R Notebook: Edge Standards Adoption and Governance Reporting
#
# This notebook summarizes interoperability governance data for an edge estate.

# %%
library(readr)
library(dplyr)

edge_assets <- read_csv('../data/sample_edge_assets.csv', show_col_types = FALSE)
edge_assets |> count(site, standard_profile, support_state)

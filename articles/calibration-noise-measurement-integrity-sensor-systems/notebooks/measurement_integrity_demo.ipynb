# %% [markdown]
# # Calibration, Noise, and Measurement Integrity Demo
#
# Explore calibration, uncertainty, SNR, drift, quality flags, and quality gates.

# %%
from pathlib import Path
import pandas as pd
root = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
records = pd.read_csv(root / 'data' / 'sample_measurement_records.csv')
records.head()

# %%
records[['sensor_id','sensor_family','calibration_expired','coefficient_mismatch','lineage_complete','traceability_complete']].head()

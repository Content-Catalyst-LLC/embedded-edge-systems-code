# %% [markdown]
# # Firmware Driver Lifecycle Review
#
# Load lifecycle events and summarize driver state coverage and failure behavior.

# %%
import pandas as pd
events = pd.read_csv('../data/device_lifecycle_events.csv')
events.groupby(['driver_id','lifecycle_state','result']).size().reset_index(name='events')
